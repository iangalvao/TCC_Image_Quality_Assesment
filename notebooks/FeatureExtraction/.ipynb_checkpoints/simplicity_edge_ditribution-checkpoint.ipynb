# %%
# %matplotlib inline
from matplotlib.pyplot import imshow
from PIL import Image
import numpy as np
import scipy.ndimage.filters
from matplotlib import pyplot as plt

# %%
img1 = "5076506.jpg"
img2 = "80184044.jpg"
img3 = "145215893.jpg"
img4 = "21852937.jpg"
img5 = "11474376103.jpg"
img6 = "10715577856.jpg"
img7 = "154740129.jpg"

# %%
img = imgs[6]

# %%
def open_image(img):
    im = Image.open('../../sample_data/1024x768/'+img)
    imArray = np.array(im)
    return imArray
#im.putalpha(255)
m = open_image(img)

#m = np.delete(m,1, 2)
#m = np.delete(m,1, 2)
print (m.shape)
w = m.shape[0]
h = m.shape[1]
#m = m.reshape(w,h)
plt.imshow(m,  vmin=0, vmax=255)
# Out:
# (768, 1024, 3)

# %%
blur = scipy.ndimage.gaussian_filter(m[:,:,0],10)
laplacian = scipy.ndimage.laplace(blur)
plt.imshow(laplacian, cmap='gray', vmin=0, vmax=255)

# %%
blur = scipy.ndimage.gaussian_filter(m[:,:,0],2)
laplacian = scipy.ndimage.laplace(blur)
plt.imshow(laplacian, cmap='gray', vmin=0, vmax=255)

# %%
imgs = ["5076506.jpg",
    "80184044.jpg",
    "145215893.jpg",
    "21852937.jpg",
    "11474376103.jpg",
    "10715577856.jpg",
    "154740129.jpg",
    "1682888994.jpg",
    "1814122396.jpg",
       "1306121832.jpg",
       "1490095554.jpg",
        "228617373.jpg"]

# %%
imArray = open_image(img)

# %%
res = []
for i in range(len(imgs)):
    imArray = open_image(imgs[i])
    edge = edge_simplicity(imArray,2)
    res.append(edge)
    print (i, edge)
    
res = np.array(res)
print (res.mean(), res.std())
# Out:
# 0 1.1157989501953125
# 1 1.1119842529296875
# 2 1.1157989501953125
# 3 1.1157989501953125
# 4 1.1138916015625
# 5 1.114527384440104
# 6 1.117706298828125
# 7 1.1164347330729165
# 8 1.1164347330729165
# 9 1.0859171549479167
# 10 1.0922749837239585
# 11 1.1145273844401042
# 1.110924614800347 0.009945933049737931

# %%
def edge_simplicity(imArray,idx,blur):
    blur = scipy.ndimage.gaussian_filter(imArray[:, :, idx],10)
    laplacian = scipy.ndimage.laplace(blur)
    #laplacian = scipy.ndimage.laplace(imArray[:, :, idx])

    
    totalSum = laplacian.sum()
    sumRows = laplacian.sum(axis=1) / totalSum
    sumColumns = laplacian.sum(axis=0) / totalSum

    f1 = hist_width(sumColumns, 0.98) / len(sumRows)
    f2 = hist_width(sumRows, 0.98) / len(sumColumns)
    return 1000*(f1 + f2) / 2

# %%
def sum_axis(laplacian):
    sumR = []
    total = 0
    check = 0
    i = 0
    for row in laplacian:
        for pixel in row:
            total += pixel
        
    for row in laplacian:
        sumR.append(0)
        for pixel in row:
            check += pixel/total
            sumR[i] += pixel/total
        i+=1

    print (total)
    print (sumR[599:609])
    print (check)
    return sumR

# %%
sumCollumns = sum_axis(laplacian)
sumRows = sum_axis(laplacian.T)
# Out:
# 49252096
# [0.0006986098622076914, 0.0007834387393381191, 0.0008429082896289331, 0.0008179753405824602, 0.0007331261597475975, 0.0006936151509166231, 0.0007085383736765235, 0.0007481102936208041, 0.000672377476077363, 0.0006699410315451344]
# 0.9999999999998653
# 49252096
# [0.0012042939248717447, 0.0012212881254840399, 0.0011613515899912164, 0.0010864918317384908, 0.0010342910076354922, 0.0010090738067269265, 0.0011776554646527138, 0.0012428303558898288, 0.001196152139393215, 0.0010839741723885213]
# 0.9999999999998791

# %%
f1 = min_range95(sumCollumns,w)
f2 = min_range95(sumRows,h)
print(f1)
print(f2)
# Out:
# MIN: 1560
# Feature: 0.8464460119370592
# MIN: 966
# Feature: 0.615678776290631
# 0.8464460119370592
# 0.615678776290631

# %%
f = []
res = []
for i in range(size[1]):
  f.append(0)
  res.append(10000)
  for j in range(i,size[1]):
    f[i] += sumR[j]
    if f[i] > 0.90:
      res[i] = j - i
      break
print (res)
print ("MIN:", min(res))
print ("Feature:", min(res)/size[1])

# %%
def hist_width(v, p):
    threshold = (1 - p) / 2
    leftsum = 0
    rightsum = 0
    l = len(v)
    end = l - 1
    start = 0
    left = 1
    right = 1
    for i in range(l):
        leftsum += v[i]
        
        rightsum += v[l - 1 - i]
        
        if (leftsum >= threshold) and left:
            start = i
            left = 0
        if (rightsum >= threshold) and right:
            end = l - 1 - i
            right = 0
        if (not left) and (not right):
            break
    if start > end:
        result = 0
    else:
        result = (end - start) / l
    return result

# %%
edge = edge_simplicity(imArray,0)
edge
# Out:
# 0.0010821024576822915

# %%
edge = edge_simplicity(imArray)
edge
# Out:
# /tmp/ipykernel_41/2599061189.py:2: DeprecationWarning: Please use `laplace` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   laplacian = scipy.ndimage.filters.laplace(imArray[:, :, 0])
# 0.0010827382405598958
