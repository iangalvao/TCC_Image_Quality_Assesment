# %%
from matplotlib.pyplot import imshow
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
from skimage.color import rgb2lab, lab2rgb

# %%
from os import listdir
from os.path import isfile, join

# %%
mypath = '../../sample_data/1024x768/RandomSample/'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
onlyfiles
# Out:
# ['5286251169.jpg',
#  '200825729.jpg',
#  '6143633711.jpg',
#  '5353332977.jpg',
#  '8728469348.jpg',
#  '8771756230.jpg',
#  '6074442813.jpg',
#  '8690378205.jpg',
#  '4780164434.jpg',
#  '5422446412.jpg',
#  '9814999.jpg',
#  '5395790450.jpg',
#  '6434876963.jpg',
#  '5435410945.jpg',
#  '5209838.jpg',
#  '8077634378.jpg',
#  '7437031540.jpg',
#  '5437634548.jpg',
#  '9317715562.jpg',
#  '7362254314.jpg',
#  '107799222.jpg',
#  '6569780821.jpg',
#  '5437097825.jpg',
#  '395147567.jpg',
#  '3973813247.jpg']

# %%
image1 = Image.open(mypath + onlyfiles[0])
image2 = Image.open(mypath + onlyfiles[1])
imArray1 = np.array(image1)
imArray2 = np.array(image2)

plt.figure(figsize=(10,5))
plt.subplot(121), plt.imshow(imArray1), plt.axis('off'), plt.title('Imagem 1', size=10)
plt.subplot(122), plt.imshow(imArray2), plt.axis('off'), plt.title('Imagem 2', size=10)
plt.show()

# %%
def plot_image(path,ax):#df,param,ax):
    

    #plt.figure()
    
    image1 = Image.open(path)
    
    imArray1 = np.array(image1)
    

    #ax.figure(figsize=(10,5))
    
    ax.imshow(imArray1)
    ax.axis('off')
    
    
    #ax.set(xlabel=param, ylabel="r2", title=param)
    #plt.subplot(121), plt.imshow(imArray1), plt.axis('off'), plt.title('Imagem 1', size=10)

    #plt.show()

# %%
mypath = '../../sample_data/1024x768/RandomSample/'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
plot, axs = plt.subplots(5,5)
print (axs)
i = 0
j = 0
for k in range(25):
    image_name = onlyfiles[k]
    plot_image(mypath+image_name, axs[i][j])
    i+=1
    if i == 5:
        i = 0
        j += 1
    if j == 5:
        j = 1
#plt.subplots_adjust(bottom=0.1, right=1.8, top=2.5)

plot.tight_layout()

#axs[0].plot(x,y)
#plot_param_r2(df, "param_max_depth",axs[1])
# Out:
# [[<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>
#   <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>
#   <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>
#   <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>
#   <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>
#   <AxesSubplot:>]]
